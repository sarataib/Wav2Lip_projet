# %% [markdown]
# ## <span style="color:blue"> Entraînement deSyncNet</span> (`color_syncnet_train.py`)

# %%
# !cd /kaggle/input/wav2lip/Wav2Lip   && python color_syncnet_train.py \
  --data_root lrs2_preprocessed/ \
  --checkpoint_dir /kaggle/working/checkpoints_syncnet
# Out:
# use_cuda: True
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# total trainable params 16435072
# ...

# %% [markdown]
# <span style="color:blue">Description</span> :
# Cette commande exécute le script <span style="color:green">color_syncnet_train.py</span> qui entraîne le modèle <span style="color:blue">Color SyncNet</span>, une variante de SyncNet focalisée sur les caractéristiques colorimétriques pour améliorer la synchronisation labiale.
#
# <span style="color:orange">--data_root</span> : chemin vers le dossier contenant les données prétraitées (ex. : <span style="color:gray">lrs2_preprocessed/</span>).
#
# <span style="color:orange">--checkpoint_dir</span> : répertoire où les points de sauvegarde (<span style="color:purple">checkpoints</span>) seront enregistrés durant l'entraînement.
#
#  <span style="color:blue">Fonctionnement</span> :
# Le script est lancé dans le répertoire <span style="color:gray">/kaggle/input/wav2lip/Wav2Lip</span> où se trouve le code source.
#
# Le modèle s’entraîne sur les données situées dans <span style="color:gray">lrs2_preprocessed/</span>.
#
# Les checkpoints sont stockés dans <span style="color:gray">/kaggle/working/checkpoints_syncnet</span> pour assurer la sauvegarde et la reprise possible de l’entraînement.
#
#
#  <span style="color:blue">Pourquoi ce modèle ?</span>
# Le modèle <span style="color:blue">Color SyncNet</span> prend en compte les nuances de couleur et les détails visuels fins, améliorant ainsi la détection de la synchronisation labiale et la qualité du rendu vidéo généré.

# %% [markdown]
# ##  <span style="color:blue">Description</span>
#
# Le script <span style="color:green">`wav2lip_train.py`</span> permet d'entraîner le modèle <span style="color:blue">Wav2Lip</span>, qui génère une synchronisation réaliste entre les mouvements des lèvres et l'audio fourni.
#
# Il repose sur deux éléments principaux :
# - un <span style="color:purple">modèle générateur</span> qui produit la vidéo,
# - et un <span style="color:purple">discriminateur SyncNet</span> chargé de vérifier la cohérence entre la vidéo générée et l’audio.
#
# ---
#
# ## <span style="color:blue">Paramètres utilisés</span>
#
# - <span style="color:orange">`--data_root`</span> : dossier contenant les vidéos prétraitées (ex. : <span style="color:gray">`lrs2_preprocessed/`</span>).
# - <span style="color:orange">`--checkpoint_dir`</span> : répertoire où les <span style="color:purple">checkpoints</span> sont sauvegardés.
# - <span style="color:orange">`--syncnet_checkpoint_path`</span> : chemin vers le modèle <span style="color:green">pré-entraîné</span> <span style="color:blue">SyncNet</span>.
#
# ---
#
# ##  <span style="color:blue">Détails techniques</span>
#
# Le modèle est entraîné avec <span style="color:green">`use_cuda: True`</span> (accélération GPU activée).
# -  Paramètres entraînables : <span style="color:purple">plus de 32 millions</span>.

# %%
# !cd /kaggle/input/wav2lip/Wav2Lip   && python color_syncnet_train.py \
  --data_root lrs2_preprocessed/ \
  --checkpoint_dir /kaggle/working/checkpoints_syncnet.pth

# %% [markdown]
# ##  <span style="color:blue">Description</span>
#
# Le script <span style="color:green">`wav2lip_train.py`</span> permet d'entraîner le modèle <span style="color:blue">Wav2Lip</span>, qui génère une synchronisation réaliste entre les mouvements des lèvres et l'audio fourni.
#
# Il repose sur deux éléments principaux :
# - un <span style="color:purple">modèle générateur</span> qui produit la vidéo,
# - et un <span style="color:purple">discriminateur SyncNet</span> chargé de vérifier la cohérence entre la vidéo générée et l’audio.
#
# ---
#
# ## <span style="color:blue">Paramètres utilisés</span>
#
# - <span style="color:orange">`--data_root`</span> : dossier contenant les vidéos prétraitées (ex. : <span style="color:gray">`lrs2_preprocessed/`</span>).
# - <span style="color:orange">`--checkpoint_dir`</span> : répertoire où les <span style="color:purple">checkpoints</span> sont sauvegardés.
# - <span style="color:orange">`--syncnet_checkpoint_path`</span> : chemin vers le modèle <span style="color:green">pré-entraîné</span> <span style="color:blue">SyncNet</span>.
#
# ---
#
# ##  <span style="color:blue">Détails techniques</span>
#
# Le modèle est entraîné avec <span style="color:green">`use_cuda: True`</span> (accélération GPU activée).
# -  Paramètres entraînables : <span style="color:purple">plus de 16 millions</span>.
